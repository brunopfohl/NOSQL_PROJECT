# %%
import sys
# !{sys.executable} -m pip install pandas pymongo --quiet

import pandas as pd
from pymongo import MongoClient
import json
import time
import warnings
import threading

warnings.filterwarnings('ignore')

def print_mongo(obj):
    """Pretty print MongoDB output"""
    print(json.dumps(obj, indent=2, default=str))

def get_mongo_router_client(max_retries=5, retry_delay=5):
    """Connect to MongoDB via the router with retry logic"""
    for attempt in range(max_retries):
        try:
            # Connect to the mongos router on 'router1:27017'
            client = MongoClient('mongodb://admin:admin@router1:27017/businessdb?authSource=admin')
            client.admin.command('ping')
            print("Successfully connected to MongoDB (via router1)")
            return client
        except Exception as e:
            print(f"Connection attempt {attempt + 1} failed: {e}")
            if attempt < max_retries - 1:
                print(f"Retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                raise

def get_shard_primary_client(shard_primary_host='shard1-1:27017'):
    """
    Connects directly to the shard's primary node (or your best guess),
    so we can run 'rs.stepDown()' and forcibly trigger a failover.
    
    NOTE: Adjust 'shard_primary_host' to match your actual primary node.
    """
    # If the shard requires authentication, specify the same admin credentials, 
    # but point to the shard node directly:
    uri = f'mongodb://admin:admin@{shard_primary_host}/admin?authSource=admin'
    shard_client = MongoClient(uri)
    # Check connection
    shard_client.admin.command('ping')
    print(f"Successfully connected to shard primary: {shard_primary_host}")
    return shard_client

# %%
router_client = get_mongo_router_client()
db = router_client.businessdb
# Out:
# Successfully connected to MongoDB (via router1)

# %%
# Verify shards:
try:
    shards_info = router_client.admin.command("listShards")
    print("\nSharded cluster details (listShards):")
    print_mongo(shards_info)
except Exception as e:
    print(f"Could not list shards: {e}")
# Out:
# Sharded cluster details (listShards):
# {
#   "shards": [
#     {
#       "_id": "shard1rs",
#       "host": "shard1rs/shard1-1:27017,shard1-2:27017,shard1-3:27017",
#       "state": 1,
#       "topologyTime": "Timestamp(1735598398, 5)"
#     },
#     {
#       "_id": "shard2rs",
#       "host": "shard2rs/shard2-1:27017,shard2-2:27017,shard2-3:27017",
#       "state": 1,
#       "topologyTime": "Timestamp(1735598398, 12)"
#     },
#     {
#       "_id": "shard3rs",
#       "host": "shard3rs/shard3-1:27017,shard3-2:27017,shard3-3:27017",
#       "state": 1,
#       "topologyTime": "Timestamp(1735598399, 6)"
#     }
#   ],
#   "ok": 1.0,
#   "$clusterTime": {
#     "clusterTime": "Timestamp(1735601194, 41)",
#     "signature": {
#       "hash": "b'i\\xab\\xa1A+2\\x94}\\xba[\\x94\\xb2\\r~\\xfb\\x91Y\\xcb\\xd06'",
#       "keyId": 7454338233845940249
#     }
#   },
#   "operationTime": "Timestamp(1735601194, 41)"
# }

# %%
organizations = db["organizations"]

# %%
def get_shard_primaries(router_client):
    """
    Returns a dict mapping:
        shard_id -> primary_host
    by parsing each shard's host string and checking who is primary
    with a direct 'hello' command.
    
    Requires that 'admin:admin' credentials *also* exist on each shard's local admin DB 
    (or a cluster-wide user recognized by each shard).
    """
    shard_primaries = {}
    try:
        shards_data = router_client.admin.command("listShards")
        for shard in shards_data.get("shards", []):
            shard_id = shard["_id"]  # e.g. 'shard1rs'
            host_def = shard["host"] # e.g. 'shard1rs/shard1-1:27017,shard1-2:27017,shard1-3:27017'

            # Split 'replicaSetName/host1,host2,host3'
            if "/" in host_def:
                _, hosts_part = host_def.split("/", 1)
                hosts = hosts_part.split(",")  # ["shard1-1:27017", "shard1-2:27017", "shard1-3:27017"]

                primary_host = None
                for host in hosts:
                    # Connect to each host, run 'hello' to see if it's primary
                    # Adjust user/password if your shard admin user is different
                    uri = f"mongodb://admin:admin@{host}/admin?authSource=admin"
                    try:
                        node_client = MongoClient(uri, serverSelectionTimeoutMS=2000)
                        hello_res = node_client.admin.command("hello")
                        # 'isWritablePrimary' is the newer field; 'ismaster' is older
                        if hello_res.get("isWritablePrimary") or hello_res.get("ismaster"):
                            primary_host = host
                            node_client.close()
                            break
                        node_client.close()
                    except Exception:
                        # If the node is down or auth fails, skip
                        pass

                shard_primaries[shard_id] = primary_host
            else:
                # If there's no slash, might be a single host unreplicated
                shard_primaries[shard_id] = host_def
    except Exception:
        pass

    return shard_primaries
    
keep_running = True

# %%
def print_shard_primaries():
    while keep_running:
        shard_primaries = get_shard_primaries(router_client)
        # E.g. "shard1rs=shard1-1:27017, shard2rs=shard2-1:27017"
        shard_info_line = ", ".join([
            f"{shard_id}={primary if primary else 'UNKNOWN'}"
            for shard_id, primary in shard_primaries.items()
        ])
        print(f"   Shard primaries: [{shard_info_line}]")
        time.sleep(2)

# %%
def continuous_operations():
    i = 0
    while keep_running:
        doc_id = f"failover-demo-{i}"
        doc = {
            "organizationId": doc_id,
            "name": f"Failover Org {i}",
            "industry": "FailoverTest",
            "founded": 2024,
            "numberOfEmployees": i * 10
        }
        start_time = time.time()
        try:
            # Insert
            organizations.insert_one(doc)
            # Find
            found_doc = organizations.find_one({"organizationId": doc_id})
            elapsed = time.time() - start_time

            if found_doc:
                print(f"[{time.strftime('%X')}] Iter={i}, inserted+found doc={doc_id}, elapsed={elapsed:.2f}s")
            else:
                print(f"[{time.strftime('%X')}] Iter={i}, could NOT find doc={doc_id}, elapsed={elapsed:.2f}s")

        except Exception as e:
            elapsed = time.time() - start_time
            print(f"[{time.strftime('%X')}] Iter={i}, ERROR: {e}, elapsed={elapsed:.2f}s")

        i += 1
        time.sleep(2)

# Start the worker
worker_thread = threading.Thread(target=continuous_operations, daemon=True)
worker_thread.start()

worker_thread_shard_primaries = threading.Thread(target=print_shard_primaries, daemon=True)
worker_thread_shard_primaries.start()

print("\nNow we'll trigger a failover on shard1 by stepping down its primary...")
# Out:
# Now we'll trigger a failover on shard1 by stepping down its primary...
# [23:26:44] Iter=0, inserted+found doc=failover-demo-0, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:46] Iter=1, inserted+found doc=failover-demo-1, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:48] Iter=2, inserted+found doc=failover-demo-2, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:50] Iter=3, inserted+found doc=failover-demo-3, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:52] Iter=4, inserted+found doc=failover-demo-4, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:54] Iter=5, inserted+found doc=failover-demo-5, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:56] Iter=6, inserted+found doc=failover-demo-6, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:26:58] Iter=7, inserted+found doc=failover-demo-7, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:00] Iter=8, inserted+found doc=failover-demo-8, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:02] Iter=9, inserted+found doc=failover-demo-9, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:04] Iter=10, inserted+found doc=failover-demo-10, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:06] Iter=11, inserted+found doc=failover-demo-11, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:08] Iter=12, inserted+found doc=failover-demo-12, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:10] Iter=13, inserted+found doc=failover-demo-13, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:12] Iter=14, inserted+found doc=failover-demo-14, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:14] Iter=15, inserted+found doc=failover-demo-15, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:16] Iter=16, inserted+found doc=failover-demo-16, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:18] Iter=17, inserted+found doc=failover-demo-17, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:20] Iter=18, inserted+found doc=failover-demo-18, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:22] Iter=19, inserted+found doc=failover-demo-19, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:24] Iter=20, inserted+found doc=failover-demo-20, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:26] Iter=21, inserted+found doc=failover-demo-21, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:28] Iter=22, inserted+found doc=failover-demo-22, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:30] Iter=23, inserted+found doc=failover-demo-23, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:32] Iter=24, inserted+found doc=failover-demo-24, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]

# %%
try:
    shard_primary_client = get_shard_primary_client('shard1-1:27017')  # or whichever node is currently primary
    # The 'replSetStepDown' command steps down the current primary for N seconds
    # forcing a new election in that replica set
    stepdown_result = shard_primary_client.admin.command({
        "replSetStepDown": 30,  # step down for 30s
        "force": True
    })
    print("\nStep down result:")
    print_mongo(stepdown_result)

except Exception as e:
    # Typically, the step-down command might throw an exception even when successful, 
    # because the primary is no longer primary right after step-down
    print(f"Caught exception while stepping down primary (often normal): {e}")
# Out:
# [23:27:34] Iter=25, inserted+found doc=failover-demo-25, elapsed=0.00s
# Successfully connected to shard primary: shard1-1:27017
#
# Step down result:
# {
#   "ok": 1.0,
#   "lastCommittedOpTime": "Timestamp(1735601249, 47)",
#   "$clusterTime": {
#     "clusterTime": "Timestamp(1735601254, 55)",
#     "signature": {
#       "hash": "b'\\xbb\\x05\\xec)\\x8cG\\xfeng|\\x91_\\xc4n\\xfc\\xcc\\xeb\\xa4\\xb2z'",
#       "keyId": 7454338233845940249
#     }
#   },
#   "operationTime": "Timestamp(1735601249, 47)"
# }
#    Shard primaries: [shard1rs=UNKNOWN, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:43] Iter=26, inserted+found doc=failover-demo-26, elapsed=7.11s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:45] Iter=27, inserted+found doc=failover-demo-27, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:47] Iter=28, inserted+found doc=failover-demo-28, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:49] Iter=29, inserted+found doc=failover-demo-29, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:51] Iter=30, inserted+found doc=failover-demo-30, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:53] Iter=31, inserted+found doc=failover-demo-31, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:55] Iter=32, inserted+found doc=failover-demo-32, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:57] Iter=33, inserted+found doc=failover-demo-33, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:27:59] Iter=34, inserted+found doc=failover-demo-34, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:01] Iter=35, inserted+found doc=failover-demo-35, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:03] Iter=36, inserted+found doc=failover-demo-36, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:05] Iter=37, inserted+found doc=failover-demo-37, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:07] Iter=38, inserted+found doc=failover-demo-38, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:09] Iter=39, inserted+found doc=failover-demo-39, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:11] Iter=40, inserted+found doc=failover-demo-40, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:13] Iter=41, inserted+found doc=failover-demo-41, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:15] Iter=42, inserted+found doc=failover-demo-42, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:17] Iter=43, inserted+found doc=failover-demo-43, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:19] Iter=44, inserted+found doc=failover-demo-44, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:21] Iter=45, inserted+found doc=failover-demo-45, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:23] Iter=46, inserted+found doc=failover-demo-46, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:25] Iter=47, inserted+found doc=failover-demo-47, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:27] Iter=48, inserted+found doc=failover-demo-48, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:29] Iter=49, inserted+found doc=failover-demo-49, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:31] Iter=50, inserted+found doc=failover-demo-50, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:33] Iter=51, inserted+found doc=failover-demo-51, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:35] Iter=52, inserted+found doc=failover-demo-52, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:37] Iter=53, inserted+found doc=failover-demo-53, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:39] Iter=54, inserted+found doc=failover-demo-54, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:41] Iter=55, inserted+found doc=failover-demo-55, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:43] Iter=56, inserted+found doc=failover-demo-56, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:45] Iter=57, inserted+found doc=failover-demo-57, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:47] Iter=58, inserted+found doc=failover-demo-58, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:49] Iter=59, inserted+found doc=failover-demo-59, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:51] Iter=60, inserted+found doc=failover-demo-60, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:53] Iter=61, inserted+found doc=failover-demo-61, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:55] Iter=62, inserted+found doc=failover-demo-62, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:57] Iter=63, inserted+found doc=failover-demo-63, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:28:59] Iter=64, inserted+found doc=failover-demo-64, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:01] Iter=65, inserted+found doc=failover-demo-65, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:03] Iter=66, inserted+found doc=failover-demo-66, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:05] Iter=67, inserted+found doc=failover-demo-67, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:07] Iter=68, inserted+found doc=failover-demo-68, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:09] Iter=69, inserted+found doc=failover-demo-69, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:11] Iter=70, inserted+found doc=failover-demo-70, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:13] Iter=71, inserted+found doc=failover-demo-71, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:15] Iter=72, inserted+found doc=failover-demo-72, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:17] Iter=73, inserted+found doc=failover-demo-73, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:19] Iter=74, inserted+found doc=failover-demo-74, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:21] Iter=75, inserted+found doc=failover-demo-75, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:24] Iter=76, inserted+found doc=failover-demo-76, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:26] Iter=77, inserted+found doc=failover-demo-77, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:28] Iter=78, inserted+found doc=failover-demo-78, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:30] Iter=79, inserted+found doc=failover-demo-79, elapsed=0.00s
# [23:29:32] Iter=80, inserted+found doc=failover-demo-80, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:34] Iter=81, inserted+found doc=failover-demo-81, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:36] Iter=82, inserted+found doc=failover-demo-82, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:38] Iter=83, inserted+found doc=failover-demo-83, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:40] Iter=84, inserted+found doc=failover-demo-84, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:42] Iter=85, inserted+found doc=failover-demo-85, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:44] Iter=86, inserted+found doc=failover-demo-86, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:46] Iter=87, inserted+found doc=failover-demo-87, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:48] Iter=88, inserted+found doc=failover-demo-88, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:50] Iter=89, inserted+found doc=failover-demo-89, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:52] Iter=90, inserted+found doc=failover-demo-90, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:54] Iter=91, inserted+found doc=failover-demo-91, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:56] Iter=92, inserted+found doc=failover-demo-92, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:29:58] Iter=93, inserted+found doc=failover-demo-93, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:00] Iter=94, inserted+found doc=failover-demo-94, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:02] Iter=95, inserted+found doc=failover-demo-95, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:04] Iter=96, inserted+found doc=failover-demo-96, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:06] Iter=97, inserted+found doc=failover-demo-97, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:08] Iter=98, inserted+found doc=failover-demo-98, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:10] Iter=99, inserted+found doc=failover-demo-99, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:12] Iter=100, inserted+found doc=failover-demo-100, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:14] Iter=101, inserted+found doc=failover-demo-101, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:16] Iter=102, inserted+found doc=failover-demo-102, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:18] Iter=103, inserted+found doc=failover-demo-103, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:20] Iter=104, inserted+found doc=failover-demo-104, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:22] Iter=105, inserted+found doc=failover-demo-105, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:24] Iter=106, inserted+found doc=failover-demo-106, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:26] Iter=107, inserted+found doc=failover-demo-107, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:28] Iter=108, inserted+found doc=failover-demo-108, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:30] Iter=109, inserted+found doc=failover-demo-109, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:32] Iter=110, inserted+found doc=failover-demo-110, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:34] Iter=111, inserted+found doc=failover-demo-111, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:36] Iter=112, inserted+found doc=failover-demo-112, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:38] Iter=113, inserted+found doc=failover-demo-113, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:40] Iter=114, inserted+found doc=failover-demo-114, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:42] Iter=115, inserted+found doc=failover-demo-115, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:44] Iter=116, inserted+found doc=failover-demo-116, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:46] Iter=117, inserted+found doc=failover-demo-117, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:48] Iter=118, inserted+found doc=failover-demo-118, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:50] Iter=119, inserted+found doc=failover-demo-119, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:52] Iter=120, inserted+found doc=failover-demo-120, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:54] Iter=121, inserted+found doc=failover-demo-121, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:56] Iter=122, inserted+found doc=failover-demo-122, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:30:58] Iter=123, inserted+found doc=failover-demo-123, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:00] Iter=124, inserted+found doc=failover-demo-124, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:02] Iter=125, inserted+found doc=failover-demo-125, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:04] Iter=126, inserted+found doc=failover-demo-126, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:06] Iter=127, inserted+found doc=failover-demo-127, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:08] Iter=128, inserted+found doc=failover-demo-128, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:10] Iter=129, inserted+found doc=failover-demo-129, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:12] Iter=130, inserted+found doc=failover-demo-130, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:14] Iter=131, inserted+found doc=failover-demo-131, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:16] Iter=132, inserted+found doc=failover-demo-132, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:18] Iter=133, inserted+found doc=failover-demo-133, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:20] Iter=134, inserted+found doc=failover-demo-134, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:22] Iter=135, inserted+found doc=failover-demo-135, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:24] Iter=136, inserted+found doc=failover-demo-136, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:26] Iter=137, inserted+found doc=failover-demo-137, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:28] Iter=138, inserted+found doc=failover-demo-138, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:30] Iter=139, inserted+found doc=failover-demo-139, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:32] Iter=140, inserted+found doc=failover-demo-140, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:34] Iter=141, inserted+found doc=failover-demo-141, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:36] Iter=142, inserted+found doc=failover-demo-142, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:38] Iter=143, inserted+found doc=failover-demo-143, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:40] Iter=144, inserted+found doc=failover-demo-144, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:42] Iter=145, inserted+found doc=failover-demo-145, elapsed=0.01s
# [23:31:44] Iter=146, inserted+found doc=failover-demo-146, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:46] Iter=147, inserted+found doc=failover-demo-147, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:48] Iter=148, inserted+found doc=failover-demo-148, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:50] Iter=149, inserted+found doc=failover-demo-149, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:52] Iter=150, inserted+found doc=failover-demo-150, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:54] Iter=151, inserted+found doc=failover-demo-151, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:56] Iter=152, inserted+found doc=failover-demo-152, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:31:58] Iter=153, inserted+found doc=failover-demo-153, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:00] Iter=154, inserted+found doc=failover-demo-154, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:02] Iter=155, inserted+found doc=failover-demo-155, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:04] Iter=156, inserted+found doc=failover-demo-156, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:06] Iter=157, inserted+found doc=failover-demo-157, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:08] Iter=158, inserted+found doc=failover-demo-158, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:10] Iter=159, inserted+found doc=failover-demo-159, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:12] Iter=160, inserted+found doc=failover-demo-160, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:14] Iter=161, inserted+found doc=failover-demo-161, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:16] Iter=162, inserted+found doc=failover-demo-162, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:18] Iter=163, inserted+found doc=failover-demo-163, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:20] Iter=164, inserted+found doc=failover-demo-164, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:22] Iter=165, inserted+found doc=failover-demo-165, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:24] Iter=166, inserted+found doc=failover-demo-166, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:26] Iter=167, inserted+found doc=failover-demo-167, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:28] Iter=168, inserted+found doc=failover-demo-168, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:30] Iter=169, inserted+found doc=failover-demo-169, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:32] Iter=170, inserted+found doc=failover-demo-170, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:34] Iter=171, inserted+found doc=failover-demo-171, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:36] Iter=172, inserted+found doc=failover-demo-172, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:38] Iter=173, inserted+found doc=failover-demo-173, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:40] Iter=174, inserted+found doc=failover-demo-174, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:42] Iter=175, inserted+found doc=failover-demo-175, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:44] Iter=176, inserted+found doc=failover-demo-176, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:46] Iter=177, inserted+found doc=failover-demo-177, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:48] Iter=178, inserted+found doc=failover-demo-178, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:50] Iter=179, inserted+found doc=failover-demo-179, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:52] Iter=180, inserted+found doc=failover-demo-180, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:54] Iter=181, inserted+found doc=failover-demo-181, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:56] Iter=182, inserted+found doc=failover-demo-182, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:32:58] Iter=183, inserted+found doc=failover-demo-183, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:00] Iter=184, inserted+found doc=failover-demo-184, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:02] Iter=185, inserted+found doc=failover-demo-185, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:04] Iter=186, inserted+found doc=failover-demo-186, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:06] Iter=187, inserted+found doc=failover-demo-187, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:08] Iter=188, inserted+found doc=failover-demo-188, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:10] Iter=189, inserted+found doc=failover-demo-189, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:12] Iter=190, inserted+found doc=failover-demo-190, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:14] Iter=191, inserted+found doc=failover-demo-191, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:16] Iter=192, inserted+found doc=failover-demo-192, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:18] Iter=193, inserted+found doc=failover-demo-193, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:20] Iter=194, inserted+found doc=failover-demo-194, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:22] Iter=195, inserted+found doc=failover-demo-195, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:24] Iter=196, inserted+found doc=failover-demo-196, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:26] Iter=197, inserted+found doc=failover-demo-197, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:28] Iter=198, inserted+found doc=failover-demo-198, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:30] Iter=199, inserted+found doc=failover-demo-199, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:32] Iter=200, inserted+found doc=failover-demo-200, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:34] Iter=201, inserted+found doc=failover-demo-201, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:36] Iter=202, inserted+found doc=failover-demo-202, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:38] Iter=203, inserted+found doc=failover-demo-203, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:40] Iter=204, inserted+found doc=failover-demo-204, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:42] Iter=205, inserted+found doc=failover-demo-205, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:44] Iter=206, inserted+found doc=failover-demo-206, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:46] Iter=207, inserted+found doc=failover-demo-207, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:48] Iter=208, inserted+found doc=failover-demo-208, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:50] Iter=209, inserted+found doc=failover-demo-209, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:52] Iter=210, inserted+found doc=failover-demo-210, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:54] Iter=211, inserted+found doc=failover-demo-211, elapsed=0.01s
# [23:33:56] Iter=212, inserted+found doc=failover-demo-212, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:33:58] Iter=213, inserted+found doc=failover-demo-213, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:00] Iter=214, inserted+found doc=failover-demo-214, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:03] Iter=215, inserted+found doc=failover-demo-215, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:05] Iter=216, inserted+found doc=failover-demo-216, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:07] Iter=217, inserted+found doc=failover-demo-217, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:09] Iter=218, inserted+found doc=failover-demo-218, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:11] Iter=219, inserted+found doc=failover-demo-219, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:13] Iter=220, inserted+found doc=failover-demo-220, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:15] Iter=221, inserted+found doc=failover-demo-221, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:17] Iter=222, inserted+found doc=failover-demo-222, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:19] Iter=223, inserted+found doc=failover-demo-223, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:21] Iter=224, inserted+found doc=failover-demo-224, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:23] Iter=225, inserted+found doc=failover-demo-225, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:25] Iter=226, inserted+found doc=failover-demo-226, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:27] Iter=227, inserted+found doc=failover-demo-227, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:29] Iter=228, inserted+found doc=failover-demo-228, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:31] Iter=229, inserted+found doc=failover-demo-229, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:33] Iter=230, inserted+found doc=failover-demo-230, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:35] Iter=231, inserted+found doc=failover-demo-231, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:37] Iter=232, inserted+found doc=failover-demo-232, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:39] Iter=233, inserted+found doc=failover-demo-233, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:41] Iter=234, inserted+found doc=failover-demo-234, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:43] Iter=235, inserted+found doc=failover-demo-235, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:45] Iter=236, inserted+found doc=failover-demo-236, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:47] Iter=237, inserted+found doc=failover-demo-237, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:49] Iter=238, inserted+found doc=failover-demo-238, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:51] Iter=239, inserted+found doc=failover-demo-239, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:53] Iter=240, inserted+found doc=failover-demo-240, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:55] Iter=241, inserted+found doc=failover-demo-241, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:57] Iter=242, inserted+found doc=failover-demo-242, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:34:59] Iter=243, inserted+found doc=failover-demo-243, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:01] Iter=244, inserted+found doc=failover-demo-244, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:03] Iter=245, inserted+found doc=failover-demo-245, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:05] Iter=246, inserted+found doc=failover-demo-246, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:07] Iter=247, inserted+found doc=failover-demo-247, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:09] Iter=248, inserted+found doc=failover-demo-248, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:11] Iter=249, inserted+found doc=failover-demo-249, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:13] Iter=250, inserted+found doc=failover-demo-250, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:15] Iter=251, inserted+found doc=failover-demo-251, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:17] Iter=252, inserted+found doc=failover-demo-252, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:19] Iter=253, inserted+found doc=failover-demo-253, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:21] Iter=254, inserted+found doc=failover-demo-254, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:23] Iter=255, inserted+found doc=failover-demo-255, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:25] Iter=256, inserted+found doc=failover-demo-256, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:27] Iter=257, inserted+found doc=failover-demo-257, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:29] Iter=258, inserted+found doc=failover-demo-258, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:31] Iter=259, inserted+found doc=failover-demo-259, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:33] Iter=260, inserted+found doc=failover-demo-260, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:35] Iter=261, inserted+found doc=failover-demo-261, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:37] Iter=262, inserted+found doc=failover-demo-262, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:39] Iter=263, inserted+found doc=failover-demo-263, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:41] Iter=264, inserted+found doc=failover-demo-264, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:43] Iter=265, inserted+found doc=failover-demo-265, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:45] Iter=266, inserted+found doc=failover-demo-266, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:47] Iter=267, inserted+found doc=failover-demo-267, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:49] Iter=268, inserted+found doc=failover-demo-268, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:51] Iter=269, inserted+found doc=failover-demo-269, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:53] Iter=270, inserted+found doc=failover-demo-270, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:55] Iter=271, inserted+found doc=failover-demo-271, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:57] Iter=272, inserted+found doc=failover-demo-272, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:35:59] Iter=273, inserted+found doc=failover-demo-273, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:01] Iter=274, inserted+found doc=failover-demo-274, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:03] Iter=275, inserted+found doc=failover-demo-275, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:05] Iter=276, inserted+found doc=failover-demo-276, elapsed=0.01s
# [23:36:07] Iter=277, inserted+found doc=failover-demo-277, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:09] Iter=278, inserted+found doc=failover-demo-278, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:11] Iter=279, inserted+found doc=failover-demo-279, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:13] Iter=280, inserted+found doc=failover-demo-280, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:15] Iter=281, inserted+found doc=failover-demo-281, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:17] Iter=282, inserted+found doc=failover-demo-282, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:19] Iter=283, inserted+found doc=failover-demo-283, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:21] Iter=284, inserted+found doc=failover-demo-284, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:23] Iter=285, inserted+found doc=failover-demo-285, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:25] Iter=286, inserted+found doc=failover-demo-286, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:27] Iter=287, inserted+found doc=failover-demo-287, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:29] Iter=288, inserted+found doc=failover-demo-288, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:31] Iter=289, inserted+found doc=failover-demo-289, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:33] Iter=290, inserted+found doc=failover-demo-290, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:35] Iter=291, inserted+found doc=failover-demo-291, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:37] Iter=292, inserted+found doc=failover-demo-292, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:39] Iter=293, inserted+found doc=failover-demo-293, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:41] Iter=294, inserted+found doc=failover-demo-294, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:43] Iter=295, inserted+found doc=failover-demo-295, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:45] Iter=296, inserted+found doc=failover-demo-296, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:47] Iter=297, inserted+found doc=failover-demo-297, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:49] Iter=298, inserted+found doc=failover-demo-298, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:51] Iter=299, inserted+found doc=failover-demo-299, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:53] Iter=300, inserted+found doc=failover-demo-300, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:55] Iter=301, inserted+found doc=failover-demo-301, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:57] Iter=302, inserted+found doc=failover-demo-302, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:36:59] Iter=303, inserted+found doc=failover-demo-303, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:01] Iter=304, inserted+found doc=failover-demo-304, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:03] Iter=305, inserted+found doc=failover-demo-305, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:05] Iter=306, inserted+found doc=failover-demo-306, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:07] Iter=307, inserted+found doc=failover-demo-307, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:09] Iter=308, inserted+found doc=failover-demo-308, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [23:37:11] Iter=309, inserted+found doc=failover-demo-309, elapsed=0.01s
# ...
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:25] Iter=1003, inserted+found doc=failover-demo-1003, elapsed=0.05s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:27] Iter=1004, inserted+found doc=failover-demo-1004, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:29] Iter=1005, inserted+found doc=failover-demo-1005, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:31] Iter=1006, inserted+found doc=failover-demo-1006, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:33] Iter=1007, inserted+found doc=failover-demo-1007, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:36] Iter=1008, inserted+found doc=failover-demo-1008, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:38] Iter=1009, inserted+found doc=failover-demo-1009, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:40] Iter=1010, inserted+found doc=failover-demo-1010, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:42] Iter=1011, inserted+found doc=failover-demo-1011, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:44] Iter=1012, inserted+found doc=failover-demo-1012, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:46] Iter=1013, inserted+found doc=failover-demo-1013, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:48] Iter=1014, inserted+found doc=failover-demo-1014, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:50] Iter=1015, inserted+found doc=failover-demo-1015, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:52] Iter=1016, inserted+found doc=failover-demo-1016, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:54] Iter=1017, inserted+found doc=failover-demo-1017, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:56] Iter=1018, inserted+found doc=failover-demo-1018, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:00:58] Iter=1019, inserted+found doc=failover-demo-1019, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:00] Iter=1020, inserted+found doc=failover-demo-1020, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:02] Iter=1021, inserted+found doc=failover-demo-1021, elapsed=0.03s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:04] Iter=1022, inserted+found doc=failover-demo-1022, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:06] Iter=1023, inserted+found doc=failover-demo-1023, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:08] Iter=1024, inserted+found doc=failover-demo-1024, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:10] Iter=1025, inserted+found doc=failover-demo-1025, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:12] Iter=1026, inserted+found doc=failover-demo-1026, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:14] Iter=1027, inserted+found doc=failover-demo-1027, elapsed=0.03s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:16] Iter=1028, inserted+found doc=failover-demo-1028, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:18] Iter=1029, inserted+found doc=failover-demo-1029, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:20] Iter=1030, inserted+found doc=failover-demo-1030, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:22] Iter=1031, inserted+found doc=failover-demo-1031, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:24] Iter=1032, inserted+found doc=failover-demo-1032, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:26] Iter=1033, inserted+found doc=failover-demo-1033, elapsed=0.04s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:28] Iter=1034, inserted+found doc=failover-demo-1034, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:30] Iter=1035, inserted+found doc=failover-demo-1035, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:32] Iter=1036, inserted+found doc=failover-demo-1036, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:34] Iter=1037, inserted+found doc=failover-demo-1037, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:36] Iter=1038, inserted+found doc=failover-demo-1038, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:38] Iter=1039, inserted+found doc=failover-demo-1039, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:40] Iter=1040, inserted+found doc=failover-demo-1040, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:42] Iter=1041, inserted+found doc=failover-demo-1041, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:44] Iter=1042, inserted+found doc=failover-demo-1042, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:46] Iter=1043, inserted+found doc=failover-demo-1043, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:48] Iter=1044, inserted+found doc=failover-demo-1044, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:50] Iter=1045, inserted+found doc=failover-demo-1045, elapsed=0.00s
# [00:01:52] Iter=1046, inserted+found doc=failover-demo-1046, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:54] Iter=1047, inserted+found doc=failover-demo-1047, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:56] Iter=1048, inserted+found doc=failover-demo-1048, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:01:58] Iter=1049, inserted+found doc=failover-demo-1049, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:00] Iter=1050, inserted+found doc=failover-demo-1050, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:02] Iter=1051, inserted+found doc=failover-demo-1051, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:04] Iter=1052, inserted+found doc=failover-demo-1052, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:06] Iter=1053, inserted+found doc=failover-demo-1053, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:08] Iter=1054, inserted+found doc=failover-demo-1054, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:10] Iter=1055, inserted+found doc=failover-demo-1055, elapsed=0.00s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:12] Iter=1056, inserted+found doc=failover-demo-1056, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:14] Iter=1057, inserted+found doc=failover-demo-1057, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:16] Iter=1058, inserted+found doc=failover-demo-1058, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:18] Iter=1059, inserted+found doc=failover-demo-1059, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:20] Iter=1060, inserted+found doc=failover-demo-1060, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:22] Iter=1061, inserted+found doc=failover-demo-1061, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:24] Iter=1062, inserted+found doc=failover-demo-1062, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:26] Iter=1063, inserted+found doc=failover-demo-1063, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:28] Iter=1064, inserted+found doc=failover-demo-1064, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:30] Iter=1065, inserted+found doc=failover-demo-1065, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:32] Iter=1066, inserted+found doc=failover-demo-1066, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:34] Iter=1067, inserted+found doc=failover-demo-1067, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:36] Iter=1068, inserted+found doc=failover-demo-1068, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:38] Iter=1069, inserted+found doc=failover-demo-1069, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:40] Iter=1070, inserted+found doc=failover-demo-1070, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:42] Iter=1071, inserted+found doc=failover-demo-1071, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:44] Iter=1072, inserted+found doc=failover-demo-1072, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:46] Iter=1073, inserted+found doc=failover-demo-1073, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:48] Iter=1074, inserted+found doc=failover-demo-1074, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:50] Iter=1075, inserted+found doc=failover-demo-1075, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:52] Iter=1076, inserted+found doc=failover-demo-1076, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:54] Iter=1077, inserted+found doc=failover-demo-1077, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:56] Iter=1078, inserted+found doc=failover-demo-1078, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:02:58] Iter=1079, inserted+found doc=failover-demo-1079, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:00] Iter=1080, inserted+found doc=failover-demo-1080, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:02] Iter=1081, inserted+found doc=failover-demo-1081, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:04] Iter=1082, inserted+found doc=failover-demo-1082, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:07] Iter=1083, inserted+found doc=failover-demo-1083, elapsed=0.03s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:09] Iter=1084, inserted+found doc=failover-demo-1084, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:11] Iter=1085, inserted+found doc=failover-demo-1085, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:13] Iter=1086, inserted+found doc=failover-demo-1086, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:15] Iter=1087, inserted+found doc=failover-demo-1087, elapsed=0.01s
# [00:03:17] Iter=1088, inserted+found doc=failover-demo-1088, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:19] Iter=1089, inserted+found doc=failover-demo-1089, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:21] Iter=1090, inserted+found doc=failover-demo-1090, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:23] Iter=1091, inserted+found doc=failover-demo-1091, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:25] Iter=1092, inserted+found doc=failover-demo-1092, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:27] Iter=1093, inserted+found doc=failover-demo-1093, elapsed=0.02s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:29] Iter=1094, inserted+found doc=failover-demo-1094, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:31] Iter=1095, inserted+found doc=failover-demo-1095, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]
# [00:03:33] Iter=1096, inserted+found doc=failover-demo-1096, elapsed=0.01s
#    Shard primaries: [shard1rs=shard1-1:27017, shard2rs=shard2-1:27017, shard3rs=shard3-1:27017]

# %%
# Stop the worker thread
keep_running = False
worker_thread.join()
worker_thread_shard_primaries.join()
